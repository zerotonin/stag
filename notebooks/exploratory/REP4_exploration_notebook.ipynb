# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_path_head = r'C:\Users\Lindsay\Documents\alexander\Deer_project\deer_code\R4_D1_LH.csv'
columns_to_keep_head = ['TagID', 'Date', 'Time', 'X', 'Y', 'Z', 'location-lat','location-lon']
head_data_in= pd.read_csv(file_path_head,usecols=columns_to_keep_head)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 file_path_head = r'C:\Users\Lindsay\Documents\alexander\Deer_project\deer_code\R4_D1_LE.csv'
#       2 columns_to_keep_head = ['TagID', 'Date', 'Time', 'X', 'Y', 'Z', 'location-lat','location-lon']
# ----> 3 head_data_in= pd.read_csv(file_path_head,usecols=columns_to_keep_head)
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\io\parsers\readers.py:1723, in TextFileReader._make_engine(self, f, engine)
#    1720     raise ValueError(msg)
#    1722 try:
# -> 1723     return mapping[engine](f, **self.options)
#    1724 except Exception:
#    1725     if self.handles is not None:
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\io\parsers\c_parser_wrapper.py:140, in CParserWrapper.__init__(self, src, **kwds)
#     136 assert self.orig_names is not None
#     137 if self.usecols_dtype == "string" and not set(usecols).issubset(
#     138     self.orig_names
#     139 ):
# --> 140     self._validate_usecols_names(usecols, self.orig_names)
#     142 # error: Cannot determine type of 'names'
#     143 if len(self.names) > len(usecols):  # type: ignore[has-type]
#     144     # error: Cannot determine type of 'names'
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\io\parsers\base_parser.py:969, in ParserBase._validate_usecols_names(self, usecols, names)
#     967 missing = [c for c in usecols if c not in names]
#     968 if len(missing) > 0:
# --> 969     raise ValueError(
#     970         f"Usecols do not match columns, columns expected but not found: "
#     971         f"{missing}"
#     972     )
#     974 return usecols
#
# ValueError: Usecols do not match columns, columns expected but not found: ['location-lat', 'location-lon']

# %%
head_data=head_data_in

# %%
head_data[['location-lat', 'location-lon']]=head_data[['location-lat', 'location-lon']].ffill() # removing the nas by filling gps loection known last
head_data[['location-lat', 'location-lon']]=head_data[['location-lat', 'location-lon']].bfill()
head_data['DateTime_Global'] = pd.to_datetime(head_data['Date'] + ' ' + head_data['Time'],format=r"%d/%m/%Y %H:%M:%S.%f")
head_data['NZ_DateTime'] = head_data['DateTime_Global'] + pd.Timedelta(hours=13)
head_data.drop(['Date', 'Time'], axis=1, inplace=True)

# %%
head_data.head()
# Out:
#                   TagID       X       Y       Z  location-lat  location-lon  \
# 0  AT1 rep4 29-30.11_S1  0.1406  0.9062 -0.0781     -38.11397     175.50941
# 1  AT1 rep4 29-30.11_S1  0.1556  0.9062 -0.0781     -38.11397     175.50941
# 2  AT1 rep4 29-30.11_S1  0.1562  0.9062 -0.0638     -38.11397     175.50941
# 3  AT1 rep4 29-30.11_S1  0.1562  0.8788 -0.0762     -38.11397     175.50941
# 4  AT1 rep4 29-30.11_S1  0.1694  0.9144 -0.0781     -38.11397     175.50941
#
#           DateTime_Global             NZ_DateTime
# 0 2018-11-28 18:33:32.000 2018-11-29 07:33:32.000
# 1 2018-11-28 18:33:32.020 2018-11-29 07:33:32.020
# 2 2018-11-28 18:33:32.040 2018-11-29 07:33:32.040
# 3 2018-11-28 18:33:32.060 2018-11-29 07:33:32.060
# 4 2018-11-28 18:33:32.080 2018-11-29 07:33:32.080

# %% [markdown]
# ## Plotting

# %% [markdown]
# ## Head Data first 50 000 measurements

# %%
# First 50 0000 measurements
df = head_data.head(1000000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Head Data first 40000 measurements

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = head_data.head(40000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Rep 4 Head Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = head_data.head(40000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Ear data first 50 000 measurements

# %%
file_path_ear = r'C:\Users\Lindsay\Documents\alexander\Deer_project\deer_code\R4_D1_LE.csv'
columns_to_keep_ear = ['TagID', 'Date', 'Time', 'X', 'Y', 'Z']
ear_data= pd.read_csv(file_path_ear, usecols=columns_to_keep_ear)
ear_data['DateTime_Global'] = pd.to_datetime(ear_data['Date'] + ' ' + ear_data['Time'],format=r"%d/%m/%Y %H:%M:%S.%f")
ear_data['NZ_DateTime'] = ear_data['DateTime_Global'] + pd.Timedelta(hours=13)
ear_data.drop(['Date', 'Time'], axis=1, inplace=True)

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = ear_data.head(50000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Ear data first 5000 measurements

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = ear_data.head(40000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Rep 4 Ear Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Ear Logger Data (no GPS)

# %%
ear_data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 ear_data.head()
#
# NameError: name 'ear_data' is not defined
