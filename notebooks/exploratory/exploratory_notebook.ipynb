# %%
import pandas as pd

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Drop TImes

# %% [markdown]
# ## REP1

# %% [markdown]
# # Head Logger Data (with GPS)

# %%
file_path_head = r'C:\Users\Lindsay\Documents\alexander\Deer_project\deer_code\AT1 Rep 1 S1Blue 12-13.11_S1.csv'
columns_to_keep_head = ['TagID', 'Date', 'Time', 'X', 'Y', 'Z', 'location-lat','location-lon']
head_data_in= pd.read_csv(file_path_head,usecols=columns_to_keep_head)

# %%
head_data=head_data_in

# %%
head_data[['location-lat', 'location-lon']]=head_data[['location-lat', 'location-lon']].ffill() # removing the nas by filling gps loection known last
head_data[['location-lat', 'location-lon']]=head_data[['location-lat', 'location-lon']].bfill()
head_data['DateTime_Global'] = pd.to_datetime(head_data['Date'] + ' ' + head_data['Time'],format=r"%d/%m/%Y %H:%M:%S.%f")
head_data['NZ_DateTime'] = head_data['DateTime_Global'] + pd.Timedelta(hours=13)
head_data.drop(['Date', 'Time'], axis=1, inplace=True)

# %%
head_data.head()
# Out:
#                     TagID       X       Y       Z  location-lat  location-lon  \
# 0  AT1 S1Blue 12-13.11_S1 -0.0156  0.9688 -0.0156     -38.11442      175.5069
# 1  AT1 S1Blue 12-13.11_S1 -0.0006  0.9688 -0.0306     -38.11442      175.5069
# 2  AT1 S1Blue 12-13.11_S1 -0.0288  0.9688 -0.0025     -38.11442      175.5069
# 3  AT1 S1Blue 12-13.11_S1 -0.0038  0.9825  0.0137     -38.11442      175.5069
# 4  AT1 S1Blue 12-13.11_S1  0.0000  0.9844 -0.0237     -38.11442      175.5069
#
#           DateTime_Global             NZ_DateTime
# 0 2018-11-11 19:11:39.000 2018-11-12 08:11:39.000
# 1 2018-11-11 19:11:39.020 2018-11-12 08:11:39.020
# 2 2018-11-11 19:11:39.040 2018-11-12 08:11:39.040
# 3 2018-11-11 19:11:39.060 2018-11-12 08:11:39.060
# 4 2018-11-11 19:11:39.080 2018-11-12 08:11:39.080

# %% [markdown]
# ## Plotting

# %% [markdown]
# ## Head Data first 50 000 measurements

# %%
# First 50 0000 measurements
df = head_data.head(50000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Head Data first 5000 measurements

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = head_data.head(5000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Ear data first 50 000 measurements

# %%
file_path_ear = r'C:\Users\Lindsay\Documents\alexander\Deer_project\deer_code\AX1 Rep 1 S1Blue 12-13.11_S1.csv'
columns_to_keep_ear = ['TagID', 'Date', 'Time', 'X', 'Y', 'Z']
ear_data_in= pd.read_csv(file_path_ear, usecols=columns_to_keep_ear)
ear_data=ear_data_in
ear_data['DateTime_Global'] = pd.to_datetime(ear_data['Date'] + ' ' + ear_data['Time'],format=r"%d/%m/%Y %H:%M:%S.%f")
ear_data['NZ_DateTime'] = ear_data['DateTime_Global'] + pd.Timedelta(hours=13)
ear_data.drop(['Date', 'Time'], axis=1, inplace=True)

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = ear_data.head(50000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Ear data first 5000 measurements

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = ear_data.head(5000)
# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['X'], label='X')
plt.plot(df['NZ_DateTime'], df['Y'], label='Y')
plt.plot(df['NZ_DateTime'], df['Z'], label='Z')

# Customize the plot
plt.title('Accelerometer Data Over Time')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Ear Logger Data (no GPS)

# %%
ear_data.head()
# Out:
#                     TagID       X       Y       Z         DateTime_Global  \
# 0  AX1 S1Blue 12-13.11_S1  0.0156 -0.0469  0.5000 2018-11-11 19:11:43.000
# 1  AX1 S1Blue 12-13.11_S1  0.0306 -0.0619  0.7250 2018-11-11 19:11:43.020
# 2  AX1 S1Blue 12-13.11_S1  0.0312 -0.0769  0.8494 2018-11-11 19:11:43.040
# 3  AX1 S1Blue 12-13.11_S1  0.0312 -0.0781  0.9144 2018-11-11 19:11:43.060
# 4  AX1 S1Blue 12-13.11_S1  0.0312 -0.0650  0.9481 2018-11-11 19:11:43.080
#
#               NZ_DateTime
# 0 2018-11-12 08:11:43.000
# 1 2018-11-12 08:11:43.020
# 2 2018-11-12 08:11:43.040
# 3 2018-11-12 08:11:43.060
# 4 2018-11-12 08:11:43.080

# %% [markdown]
# # Functions and Data Cleaning

# %%
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from scipy.signal import butter, lfilter
from scipy.signal import find_peaks
from scipy.signal import savgol_filter, peak_prominences

# %%
def normalise_data(data, cols=['X', 'Y', 'Z']):
    """
    Normalise accellerometer columns in a Pandas DataFrame.

    Parameters:
    - data (pd.DataFrame): The input DataFrame.
    - cols (list): List of column names to normalize. Default is ['X', 'Y', 'Z'].

    Returns:
    - pd.DataFrame: The  normalized columns.
    """

    # Create a copy of the DataFrame to avoid modifying the original data

    # Initialize the MinMaxScaler
    scaler = StandardScaler()

    # Normalise specified columns
    normalised_data = pd.DataFrame(scaler.fit_transform(data[cols]),columns=cols)
    return normalised_data

def correct_calibration(data, calibration_row, cols=['X', 'Y', 'Z']): # calibrate ACCELLEROMETER VALS BY RMOVING THE FIRST VALUE
    cols_to_calibrate = data[cols]
    
    for column in cols_to_calibrate:
        cols_to_calibrate[column] =cols_to_calibrate[column]- calibration_row[column][0]
    return cols_to_calibrate

def make_absolute(data):
    """
    Make each column in a Pandas DataFrame the absolute value of itself.

    Parameters:
    - data (pd.DataFrame): The input DataFrame.

    Returns:
    - pd.DataFrame: The DataFrame with absolute values for each column.
    """

    # Create a copy of the DataFrame to avoid modifying the original data
    absolute_data = data.copy()

    # Take the absolute value of each column
    absolute_data = absolute_data.map(abs)
    return absolute_data


def sum_columns(data, columns_to_sum=['X', 'Y', 'Z']):
    """
    Sum together specified columns in a Pandas DataFrame.

    Parameters:
    - data (pd.DataFrame): The input DataFrame.
    - columns_to_sum (list): List of column names to sum together.

    Returns:
    - pd.Series: A Series representing the sum of the specified columns.
    """

    # Sum together specified columns
    result_series = data[columns_to_sum].sum(axis=1)

    return result_series

def get_total_absolute_accelleration(data):
    """
    Calculate the total absolute acceleration for each row in a DataFrame.

    Parameters:
    - data (pd.DataFrame): The input DataFrame containing acceleration data.

    Returns:
    - pd.Series: A Series representing the total absolute acceleration for each row.
    """
    normalised_cols = normalise_data(data)
    absolute_cols = make_absolute(normalised_cols)
    summed_cols = sum_columns(absolute_cols)
    return summed_cols

def get_calibrated_absolute_accelleration(data, calibration_row):
    """
    Calculate the total absolute acceleration for each row in a DataFrame.

    Parameters:
    - data (pd.DataFrame): The input DataFrame containing acceleration data.

    Returns:
    - pd.Series: A Series representing the total absolute acceleration for each row.
    """
    normalised_cols = correct_calibration(data,calibration_row)
    absolute_cols = make_absolute(normalised_cols)
    summed_cols = sum_columns(absolute_cols)
    return summed_cols

def high_pass_filter(data, columns, cutoff_frequency=0.1, sampling_frequency=5, order=2):
    """
    Apply a high-pass filter to a Pandas DataFrame.

    Parameters:
    - data (pd.DataFrame): The input DataFrame.
    - cutoff_frequency (float): The cutoff frequency for the high-pass filter.
    - sampling_frequency (float): The sampling frequency of the data.
    - order (int): The order of the filter.

    Returns:
    - pd.DataFrame: The DataFrame with high-pass filtered values.
    """

    # Create a copy of the DataFrame to avoid modifying the original data
    filtered_data = data.copy()

    # Calculate the Nyquist frequency
    nyquist_frequency = 0.5 * sampling_frequency

    # Design a high-pass Butterworth filter
    b, a = butter(order, cutoff_frequency / nyquist_frequency, btype='highpass',output='ba')

    # Apply the filter to each column
    columns_to_hipass= data[columns]
    for column in columns_to_hipass:
        columns_to_hipass[column] = lfilter(b, a, data[column])

    return columns_to_hipass




def find_matching_peaks(signal1, signal2, margin_of_error=2):
    peaks1, _ = find_peaks(signal1)
    peaks2, _ = find_peaks(signal2)

    matching_indices = []

    for peak1_index in peaks1:
        for peak2_index in peaks2:
            time_difference = abs(peak1_index - peak2_index)
            if time_difference <= margin_of_error:
                matching_indices.append((peak1_index, peak2_index))
                break  # Move to the next peak in the first signal

    return matching_indices

# %% [markdown]
# ## Exploration of prominance

# %%
data_window_head=head_data.head(5000)
calibration_row_head=head_data.head(1)
data_window_head["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head, calibration_row=calibration_row_head)
peaks,_ = find_peaks(data_window_head["absolute_accelleration"])
proms=peak_prominences(data_window_head["absolute_accelleration"],peaks)[0]
data_window_head["prom"]=0
for i, p in enumerate(peaks):
    data_window_head["prom"][p]=proms[i]
# Out:
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\1600965321.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_to_calibrate[column] =cols_to_calibrate[column]- calibration_row[column][0]
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\93238948.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_window_head["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head, calibration_row=calibration_row_head)
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\93238948.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_window_head["prom"]=0
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\93238948.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_window_head["prom"][p]=proms[i]
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\93238948.py:8: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '0.003700000000000002' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data_window_head["prom"][p]=proms[i]

# %%
head_data=head_data_in.copy()
ear_data=ear_data_in.copy()
calibration_row_head=head_data.head(1)
data_window_head_end=head_data.tail(20000).reset_index()
data_window_head_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head_end,calibration_row=calibration_row_head)
data_window_ear_end=ear_data.tail(20000).reset_index()
data_window_ear_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_ear_end, calibration_row=calibration_row_ear)



peaks_head_end,_ = find_peaks(data_window_head_end["absolute_accelleration"])
proms_head=peak_prominences(data_window_head_end["absolute_accelleration"],peaks_head_end)[0]
data_window_head_end["prom"]=0
for i, p in enumerate(peaks):
    data_window_head_end["prom"][p]=proms_head[i]
    
peaks_ear_end,_ = find_peaks(data_window_ear_end["absolute_accelleration"])
proms_ear=peak_prominences(data_window_ear_end["absolute_accelleration"],peaks_ear_end)[0]
data_window_ear_end["prom"]=0
for i, p in enumerate(peaks):
    data_window_ear_end["prom"][p]=proms_head[i]
# Out:
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\1600965321.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_to_calibrate[column] =cols_to_calibrate[column]- calibration_row[column][0]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 7
#       5 data_window_head_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head_end,calibration_row=calibration_row_head)
#       6 data_window_ear_end=ear_data.tail(20000).reset_index()
# ----> 7 data_window_ear_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_ear_end, calibration_row=calibration_row_ear)
#      11 peaks_head_end,_ = find_peaks(data_window_head_end["absolute_accelleration"])
#      12 proms_head=peak_prominences(data_window_head_end["absolute_accelleration"],peaks_head_end)[0]
#
# NameError: name 'calibration_row_ear' is not defined

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = data_window_head_end

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration'], label='accelleration')
plt.plot(df['NZ_DateTime'], df['prom'], label='prominance')
# Customize the plot
plt.title('Prominance of accellerations of head in last 20000 measurements with accelleration')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Plotting prominance of both head and tail at end of time

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = data_window_head_end
df1= data_window_ear_end
# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['prom'], label='prominance_head')
plt.plot(df1['NZ_DateTime'], df1['prom'], label='prominance_ear')
# Customize the plot
plt.title('Prominance of accelleration peaks for head and ear rep 1 deer 1 last 20 000 measurements')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Investgating correlation between signals

# %%
# Assuming your signals are stored in pandas DataFrames df1 and df2
signal1 = data_window_head_end['prom'].values
signal2 = data_window_ear_end['prom'].values
thershold=0.8
# Compute cross-correlation
cross_corr = np.correlate(signal1, signal2, mode='full')

# Find the lag corresponding to the maximum correlation
lag = np.argmax(cross_corr) - len(signal1) + 1

# Plot cross-correlation
plt.figure(figsize=(10, 5))
plt.plot(np.arange(-len(signal1) + 1, len(signal2)), cross_corr)
plt.axvline(lag, color='r', linestyle='--', label=f'Lag = {lag}')
plt.xlabel('Lag')
plt.ylabel('Cross-correlation')
plt.title('Cross-correlation of Signals')
plt.legend()
plt.grid(True)
plt.show()

# Check if the maximum correlation is close to 1
max_corr = np.max(cross_corr)
if max_corr > threshold:
    print("Maximum correlation:", max_corr)
    print("Lag (in samples):", lag)
    print("Signals are likely similar with a phase shift.")
else:
    print("Signals are not similar.")
# Out:
# Maximum correlation: 423.09400103
# Lag (in samples): 0
# Signals are likely similar with a phase shift.

# %% [markdown]
# # Actual code to use now

# %%
data_window_head=head_data.head(5000)
calibration_row_head=head_data.head(1)
data_window_head["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head, calibration_row=calibration_row_head)
data_window_ear=ear_data.head(5000)
calibration_row_ear=ear_data.head(1)
data_window_ear["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_ear,calibration_row_ear)


peaks_head,_ = find_peaks(data_window_head["absolute_accelleration"], prominence=1)
peaks_ear,_ = find_peaks(data_window_head["absolute_accelleration"], prominence=1)
# Out:
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_7616\1600965321.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_to_calibrate[column] =cols_to_calibrate[column]- calibration_row[column][0]
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_7616\2482412901.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_window_head["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head, calibration_row=calibration_row_head)
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_7616\1600965321.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_to_calibrate[column] =cols_to_calibrate[column]- calibration_row[column][0]
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_7616\2482412901.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_window_ear["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_ear,calibration_row_ear)

# %% [markdown]
# ## For Tail

# %%
data_window_head_end=head_data.tail(10000)
data_window_head_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head_end,calibration_row=calibration_row_head)
data_window_ear_end=ear_data.tail(10000)
data_window_ear_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_ear_end, calibration_row=calibration_row_ear)


peaks_head_end,_ = find_peaks(data_window_head_end["absolute_accelleration"], prominence=1)
peaks_ear_end,_ = find_peaks(data_window_head_end["absolute_accelleration"], prominence=1)
# Out:
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\1600965321.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cols_to_calibrate[column] =cols_to_calibrate[column]- calibration_row[column][0]
# C:\Users\Lindsay\AppData\Local\Temp\ipykernel_18616\4046836568.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_window_head_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head_end,calibration_row=calibration_row_head)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       2 data_window_head_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_head_end,calibration_row=calibration_row_head)
#       3 data_window_ear_end=ear_data.tail(10000)
# ----> 4 data_window_ear_end["absolute_accelleration"]=get_calibrated_absolute_accelleration(data_window_ear_end, calibration_row=calibration_row_ear)
#       7 peaks_head_end,_ = find_peaks(data_window_head_end["absolute_accelleration"], prominence=1)
#       8 peaks_ear_end,_ = find_peaks(data_window_head_end["absolute_accelleration"], prominence=1)
#
# NameError: name 'calibration_row_ear' is not defined

# %% [markdown]
# ## Script to run Functions

# %%
# head_data["absolute_accelleration"]= get_total_absolute_accelleration(head_data)
# ear_data["absolute_accelleration"]= get_total_absolute_accelleration(ear_data)
# head_data["absolute_accelleration_hipass"]= high_pass_filter(head_data, columns=["absolute_accelleration"])
# ear_data["absolute_accelleration_hipass"]= high_pass_filter(ear_data, columns=["absolute_accelleration"])
# head_data["absolute_accelleration_savgol"]= high_pass_savgol(head_data, columns=["absolute_accelleration"])
# ear_data["absolute_accelleration_savgol"]= high_pass_savgol(ear_data, columns=["absolute_accelleration"])

# %% [markdown]
# ## Plots Of Absolute Movement Over Time Head

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = data_window_head
df1= data_window_ear
# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration'], label='accelleration_head')
plt.plot(df1['NZ_DateTime'], df1['absolute_accelleration'], label='accelleration_ear')
# Customize the plot
plt.title('Total head Acceleration Data Over Time Rep 1 Deer 1')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# ## Plots Of Absolute Movement Over Time Head At end

# %%
data_window_ear_end.tail()
# Out:
#                           TagID       X       Y       Z  \
# 8749296  AX1 S1Blue 12-13.11_S1  0.0456 -0.1250  0.9831
# 8749297  AX1 S1Blue 12-13.11_S1  0.0322 -0.1259  0.9688
# 8749298  AX1 S1Blue 12-13.11_S1  0.0463 -0.1406  0.9681
# 8749299  AX1 S1Blue 12-13.11_S1  0.0312 -0.1406  0.9531
# 8749300  AX1 S1Blue 12-13.11_S1  0.0000  0.0000  0.0000
#
#                 DateTime_Global             NZ_DateTime  \
# 8749296 2018-11-13 19:48:08.920 2018-11-14 08:48:08.920
# 8749297 2018-11-13 19:48:08.940 2018-11-14 08:48:08.940
# 8749298 2018-11-13 19:48:08.960 2018-11-14 08:48:08.960
# 8749299 2018-11-13 19:48:08.980 2018-11-14 08:48:08.980
# 8749300 2018-11-13 19:48:08.000 2018-11-14 08:48:08.000
#
#          absolute_accelleration
# 8749296                  0.5912
# 8749297                  0.5644
# 8749298                  0.5925
# 8749299                  0.5624
# 8749300                  0.5625

# %%
data_window_head_end.tail()
# Out:
#                           TagID       X       Y       Z  location-lat  \
# 8750996  AT1 S1Blue 12-13.11_S1  0.4219  0.5625  0.7031     -38.11417
# 8750997  AT1 S1Blue 12-13.11_S1  0.4297  0.5625  0.6875     -38.11417
# 8750998  AT1 S1Blue 12-13.11_S1  0.4375  0.5625  0.6719     -38.11417
# 8750999  AT1 S1Blue 12-13.11_S1  0.4375  0.5625  0.6719     -38.11417
# 8751000  AT1 S1Blue 12-13.11_S1  0.0000  0.0000  0.0000     -38.11417
#
#          location-lon         DateTime_Global             NZ_DateTime  \
# 8750996     175.50809 2018-11-13 19:48:38.920 2018-11-14 08:48:38.920
# 8750997     175.50809 2018-11-13 19:48:38.940 2018-11-14 08:48:38.940
# 8750998     175.50809 2018-11-13 19:48:38.960 2018-11-14 08:48:38.960
# 8750999     175.50809 2018-11-13 19:48:38.980 2018-11-14 08:48:38.980
# 8751000     175.50809 2018-11-13 19:48:39.000 2018-11-14 08:48:39.000
#
#          absolute_accelleration
# 8750996                  1.5625
# 8750997                  1.5547
# 8750998                  1.5469
# 8750999                  1.5469
# 8751000                  1.0000

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = data_window_head_end
df1= data_window_ear_end
# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration'], label='accelleration_head')
plt.plot(df1['NZ_DateTime'], df1['absolute_accelleration'], label='accelleration_ear')
# Customize the plot
plt.title('Total head Acceleration Data Over Time Rep 1 Deer 1')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = data_window_head_end
df1= data_window_ear_end
# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration'], label='accelleration_head')
plt.plot(df1['NZ_DateTime'], df1['absolute_accelleration'], label='accelleration_ear')
# Customize the plot
plt.title('Total head Acceleration Data Over Time Rep 1 Deer 1')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = data_window_head

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration'], label='accelleration')
plt.plot(df['NZ_DateTime'], df['prom'], label='prominance')
# Customize the plot
plt.title('Total ear Acceleration Data Over Time Rep 1 Deer 1')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'prom'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[188], line 9
#       7 # Plot X, Y, and Z over time
#       8 plt.plot(df['NZ_DateTime'], df['absolute_accelleration'], label='accelleration')
# ----> 9 plt.plot(df['NZ_DateTime'], df['prom'], label='prominance')
#      10 # Customize the plot
#      11 plt.title('Total ear Acceleration Data Over Time Rep 1 Deer 1')
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\Lindsay\anaconda3\envs\deer_project_2\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'prom'

# %% [markdown]
# # High passed Signal

# %%
# Downsample the data to a manageable size, for example, every 1000th data point
df = head_data.head(5000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration_hipass'], label='accelleration')

# Customize the plot
plt.title('Total head Acceleration Data Over Time High Passed Rep 1 Deer 1')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Downsample the data to a manageable size, for example, every 1000th data point
df = ear_data.head(5000)

# Set up the plot
plt.figure(figsize=(12, 6))

# Plot X, Y, and Z over time
plt.plot(df['NZ_DateTime'], df['absolute_accelleration_hipass'], label='accelleration')

# Customize the plot
plt.title('Total ear Acceleration Data Over Time High Passed Rep 1 Deer 1')
plt.xlabel('Time')
plt.ylabel('Accelerometer Values')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
